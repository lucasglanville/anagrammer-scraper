# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import warnings
from urllib.parse import urljoin
warnings.filterwarnings("ignore")

# %%
def fetch_clues(words):
    for word in words:
        print(f"\nWord: {word}\n" + "=" * (6 + len(word)))

        # Base URL structure for each word
        base_url = f"https://www.anagrammer.com/crossword/answer/{word}/1/1/1/1/"

        # Fetch the max page number
        try:
            response = requests.get(f"{base_url}1")
            response.raise_for_status()
            soup = BeautifulSoup(response.content, 'html.parser')

            pagination = soup.select(".pagination")[1]
            page_numbers = [int(link.get_text(strip=True)) for link in pagination.find_all("a") if link.get_text(strip=True).isdigit()]
            max_page = max(page_numbers) + 1 if page_numbers else 1
        except Exception as e:
            print(f"Error fetching pagination for '{word}': {e}")
            continue

        # Loop through each page for the word
        for page_num in range(1, max_page):
            url = f"{base_url}{page_num}"
            
            try:
                response = requests.get(url)
                response.raise_for_status()
                soup = BeautifulSoup(response.content, 'html.parser')

                # Locate the table containing clues
                header = soup.find("th", string="Last Seen in these Crosswords & Puzzles")
                if not header:
                    continue
                table = header.find_parent("table")

                # Extract relevant clues from the table
                for a_tag in table.find_all("a", href=True):
                    clue_sources = ["The-Times---Cryptic", "The-Telegraph---Cryptic", "The-Telegraph---Toughie", "The-Guardian---Cryptic-crossword"]
                    if any(source in a_tag["href"] for source in clue_sources):
                        full_url = urljoin(base_url, a_tag["href"])

                        # Fetch and parse each clue page
                        try:
                            clue_response = requests.get(full_url)
                            clue_response.raise_for_status()
                            clue_soup = BeautifulSoup(clue_response.content, 'html.parser')

                            # Find and print clues relevant to the word
                            for row in clue_soup.find_all("tr"):
                                columns = row.find_all("td")
                                if len(columns) == 2:
                                    clue = columns[0].get_text(strip=True)
                                    answer = columns[1].get_text(strip=True)
                                    if answer.lower() == word:
                                        print(f"{clue} ({len(word)})")
                        except Exception as e:
                            print(f"Error fetching clue for '{word}' at {full_url}: {e}")
            except Exception as e:
                print(f"Error fetching page {page_num} for '{word}': {e}")

# %%
# List of words
words = ["riel", "rued", "reek", "reed", "rhea", "reel", "reef", "ryes", "rues", "roed"]
fetch_clues(words)
# Out:
# Word: riel
# ==========
# Oxford college without love or money (4)
#
# Word: rued
# ==========
# Deplored coarse speaking (4)
# Regretted being churlish, by the sound of it? (4)
# Was unhappy about drive round much of Europe, heading west (4)
# Regretted impolite sound (4)
# Felt sorry about making vulgar broadcast (4)
# Felt bad about heartless objection, in retrospect (4)
# Regretted making left turn to enter (4)
# Regretted vulgar sounds (4)
# Regretted being coarse, it's said (4)
# Here regretted having sounded cross (4)
# Regretted having reflected grandeur of lost ancestor (4)
# Was sorry for sounding discourteous (4)
# Regretted sounding offensive (4)
# Regretted being impolite to the audience (4)
# Regretted sounding discourteous (4)
# Herb's daughter was remorseful (4)
# Was sorry when Herb died (4)
# Regretted being impolite in speech (4)
# Felt remorse for being ill-mannered in speech (4)
# Regretted being offensive in speech (4)
# Regretted being offensive in speech (4)
# Regretted being offensive in speech (4)
# Regretted being offensive in speech (4)
#
# Word: reek
# ==========
# Attic possibly has roof blown off, creating stink (4)
# Hum Gluck's overture out of Iphigenia, say (4)
# Smell detected from 3 km? (4)
# Hum, while doing the backstroke in Lake Erie? (4)
# Good to avoid unintelligible words and hum a lot! (4)
# Effluvium coming from bay, not cape (4)
# Fume with free perks only now and then (4)
# Strong smell Indian cooking initially leaves (4)
# Stream with source blocked produces stink (4)
# Smell smoke (4)
# Major astronomer losing place over tainted atmosphere? (4)
# Smell from bay caught drifting away (4)
# Miasma's radius that's alarming (4)
# European's lost final of ping pong (4)
# Smell smoke? Attic's spared initially (4)
# During spree kept producing smell (4)
# Smell from speaker's overturned drink (4)
# Smell smoke (4)
# Cove losing head causing stink (4)
# Interjection coming from Rex first because of the smell (4)
# Smell strongly of smoke (4)
# Not the first Grecian smell (4)
# Not the first Grecian smell (4)
# Not the first Grecian smell (4)
# Not the first Grecian smell (4)
# European leader deposed, in bad odour (4)
#
# Word: reed
# ==========
# Marsh grass ruminant animal pulled up (4)
# For audience interpret oboe part (4)
# Ancient arrow's point, bloodied all around? (4)
# Grass some ungulates rejected (4)
# Part of an instrument that naturally grows wet (4)
# Grass object of hunt up (4)
# Grass as part of fat-free diet (4)
# One�s got out of bed to go on the roof (4)
# Pipe repaired, the two left (4)
# One of two in a 25's study, say (4)
# Thatcher may have applied this doctrine after polling (4)
# Grass on press bigwig? (4)
# Grass blown in the wind? (4)
# Grass forming part of meat-free diet (4)
# Rush animal from below (4)
# Rush animal from below (4)
# Rush animal from below (4)
# Rush animal from below (4)
# Learn by ear clarinet part (4)
# Buck up with that pipe (4)
# Send ruminant up for grass (4)
# Grass required to bring up herbivores (4)
# For audience, interpret a piece for organ (4)
# Reputed to have put out to grass (4)
# See wot the buk says about the plant? (4)
# Stalk animals heading west (4)
# Buck up with the pipe! (4)
# Buck up, 9? (4)
# ...grass right by rising river (4)
# Oliver perhaps ashamed about 'More', in the end (4)
# Weak thing - buck up! (4)
# Soundly study the plant (4)
# Grass in which animal rolls over (4)
# Rush about with Edwin (4)
# Grass seen as river runs around (4)
# Said 'See what it says,' in a rush (4)
# Animals retreating into long grass (4)
# Three-noted pipe (4)
# Animals raised on grass (4)
# Film director in a rush (4)
# Rush the animals back (4)
# Carol in the grass (4)
# See 13 (4)
# Rush the animals back (4)
# Does, perhaps, return in a rush (4)
# Does, perhaps, return in a rush (4)
# See 9 (4)
# Does, perhaps, go back to grass (4)
# Oliver, ashamed about 'More', in the end (4)
# Rush about with top newsman (4)
# Plant developed for manufacture of instruments (4)
# Ruminants looking round for grass (4)
# Animal on its back in tall grass (4)
# Animal on its back in tall grass (4)
# Animal on its back in tall grass (4)
# Animal on its back in tall grass (4)
#
# Word: rhea
# ==========
# Hear cuckoo and another bird (4)
# Bird featured in banner headline (4)
# Bird caged by our headmaster (4)
# Artist capturing male bird that can't fly (4)
# In Chester he accommodated a flightless bird (4)
# Artist catches male bird (4)
# Satellite of Saturn partly seen overhead (4)
# Bird he’s introduced to artist (4)
# Artist embracing explosive goddess (4)
# In poor health, creature that can't fly (4)
# Among the gunners he gets the bird (4)
# Summer heat is too much for this bird (4)
# Bird that's grounded wherever heather protects it (4)
# When rook flies west, catch the sound of larger bird (4)
# Bird to catch, tail first (4)
# Bird said to be back (4)
# Are hyena or cheetah regularly seeing this bird twice? (4)
# Bird found in or near Headingley (4)
# Bird overhead hides (4)
# Bird caught in your headlights (4)
# Moon goddess (4)
# Artist manages to capture the male bird (4)
# One unable to take off some banner headline (4)
# Bird not taking off in summer heat (4)
# Newspaper headline features bird (4)
# Hare bumped into ostrich (4)
# Satellite one can't get up into the air (4)
# Principal mostly applied to right winger that's grounded (4)
# One can't take off part of cylinder head (4)
# In poorer health, bird unable to fly (4)
# Bird runs ahead with wings clipped (4)
# Listen to, with rook moving, another bird (4)
# In Ecuador he acknowledged a S American runner (4)
# Large bird camouflaged by tall grass or heather (4)
# A bird is overhead, but no sort of dove (4)
# Having run, not quite catch song of bird (4)
# Non-flier in poor health (4)
# Fast runner the governor encountered in Burlington House (4)
# Bird's bottom, say (4)
# Bird's behind, we hear (4)
# Reportedly it's brought up by the slowest bird (4)
# In conversation, bring up bird (4)
# Goddess given the bird (4)
# Male rook leading a bird (4)
# It can't fly from predator - heavens! (4)
# Run to the front - hear this bird (4)
# Bird in poor health (4)
# Bird in poor health (4)
# Bird in poor health (4)
# Bird in poor health (4)
#
# Word: reel
# ==========
# Part of film is material for audience (4)
# River fish's swim (4)
# Victor snubbed in party dance (4)
# Lech returning for a dance (4)
# Look suggestively back in the dance (4)
# Dance to cast a lustful eye over (4)
# Part of film may be true, it's said (4)
# Undesirable look about lively dance (4)
# Swim in three lanes (4)
# Sound coming from concrete drum (4)
# Feel giddy as lascivious look picked up (4)
# Nonconformist losing heart in dance (4)
# Part of film is true, reportedly (4)
# Highlanders may do so even when sober (4)
# Spin not made up, as some might say (4)
# Dance party has not reduced volume (4)
# Look over section of film (4)
# Lecherously eye up for a dance (4)
# How to bring in little river fish? (4)
# Show astonishment as insurgent loses heart (4)
# With lid off fish basket reveals angler's aid (4)
# Sound description of McCoy's dance? (4)
# Falter as revolutionary losing heart (4)
# Swim in river with slippery fish (4)
# It's used to catch small river fish (4)
# Taking top off fish basket reveals this part of angler's kit (4)
# Some of the film is true to life, we hear (4)
# Folk dance when dissenter has ousted bishop (4)
# Maverick has lost his heart in a dance (4)
# Rock music you can dance to (4)
# Part of film is not fictitious, we hear (4)
# Lewdly look up 1? (4)
# Merrymaking with no very short dance (4)
# Five leaving orgy for dance (4)
# Wind up drunk apparently (4)
# Totter returning dirty look (4)
# Part of film is serious, according to report (4)
# Wind blows making one do this? (4)
# Totter in turn with 3 (4)
# Sound, concrete rock (4)
# Revolutionary losing heart gets to falter (4)
# It's used in casting part of a film (4)
# Genuine-sounding spin (4)
# Lady Bird left to stagger (4)
# Dance that's authentic, so it's said (4)
# Look back and become dizzy (4)
# Whirl around and grin back (4)
# Rock dance? (4)
# River fish, it is attached to fishing-rod (4)
# Dance and swim (4)
# Air - or wind (4)
# About to join the Spanish dance (4)
# Part of film is serious, according to report (4)
# Speak proper - is one doing a wind-up? (4)
# Stagger out of some film (4)
# Lurch, returning a dirty look (4)
# Cotton on to this kind of dancing (4)
# Look slyly back to dance (4)
# Dance in long stretch of film (4)
# Agitator to lose heart and wobble (4)
# Authentic sound makes us sway (4)
# Heartless revolutionary's sway (4)
# Stagger in before eleven o'clock (4)
# Rock dance (4)
# Part of film has proper sound (4)
# Stagger to the dance (4)
# Fishing equipment set right, fish (4)
# Turn to give the eye to and lose your balance (4)
# Wind up with a lively dance? (4)
# Authentic-sounding music for dance (4)
# Drive away - no parking for the dance (4)
# Drive away - no parking for the dance (4)
# Drive away - no parking for the dance (4)
# Drive away - no parking for the dance (4)
# It's used to catch small river fish (4)
# Something to fish with for river fish (4)
# Wind makes one stagger about (4)
# Angler's equipment is authentic, we hear (4)
#
# Word: reef
# ==========
# Person recruited starts to examine food chain in water (4)
# Bank's not entirely free finance (4)
# One can get free from this knot (4)
# Admire efforts to ring bank (4)
# Bank right to reject payment (4)
# Hazard at sea -- do something to reduce canvas (4)
# Official covering English bank (4)
# The knot sailors try to avoid (4)
# A knot that seamen consider dangerous (4)
# Judge imprisoning head of European bank (4)
# Knot, turnstone etc may feed here (4)
# No charge first to last, one gathered on yacht (4)
# Rocks about going over eastern France (4)
# Rocky part of sail (4)
# It's not too hard to get free from this knot (4)
# Bank where judge keeps euros at first (4)
# Such a knot not tied — fine to take the other end (4)
# Bank not imposing a charge first to last (4)
# River charge raised means potential danger for ships (4)
# Part of sail that could spell danger to sailor (4)
# Bank in free fall (4)
# Knot sailors try to avoid (4)
# Recalling Edward Elgar for starters: "Where Corals Lie"? (4)
# Folding part of sail may be treacherous for ship (4)
# Hazard to sailors taken in when it's blowy (4)
# Some more effective barrier (4)
# Knot sailors try to avoid (4)
# Bank official retaining energy (4)
# Bank sailors try to avoid? (4)
# The knot sailors avoid (4)
# See 15 (4)
# Bank without charges first to sink completely (4)
# One whistles, crossing close to extreme marine hazard (4)
# Marine formation incorporating part of tree fern (4)
# The work of 12 is tied (4)
# Main chain putting price right up (4)
# King repelled charge on the rocks (4)
# The sort of knot sailors consider dangerous (4)
# Bank that may be taken in (4)
# Reduce sail - rocks in sight! (4)
# It can be taken in a bank (4)
# Bar open to all, beginning to end (4)
# Bar open to all, beginning to end (4)
# Bar open to all, beginning to end (4)
# Bar open to all, beginning to end (4)
#
# Word: ryes
# ==========
# Grasses grow upwards, as you might say (4)
# Increase mentioned in cereals (4)
# Romeo agreed to provide drinks (4)
#
# Word: rues
# ==========
# Is sorry about deception auditor’s picked up (4)
# Is sorry to announce hoax (4)
# Regrets deception on the radio (4)
# Regrets controls, a Liberal gone astray (4)
# Tours streets — and wishes one hadn't? (4)
# Regrets making heartless laws (4)
# Is sorry to say it's a ploy (4)
# Horsing around sure brings regrets (4)
# Regrets some untrue statements (4)
# Regrets on seeing the roads in France! (4)
# Regrets reporting deception (4)
# Regrets government's ignoring Liberal leader (4)
#
# Word: roed
# ==========
# Error fetching pagination for 'roed': list index out of range

# %%
# List of words
words = ["slaloming", "seasoning", "shadowing", "shamoying"]
fetch_clues(words)
# Out:
# Word: slaloming
# ===============
# Error fetching pagination for 'slaloming': list index out of range
#
# Word: seasoning
# ===============
# Period home with good taste is what I provide (9)
# Salt recollected in sea song (9)
# Relish being cool in shanty (9)
# Shanty about popular salt, for example (9)
# One signs a release for timber treatment (9)
# Relish a few months in Gateshead (9)
# Shanty about popular salt? (9)
# Salt, possibly, starts to improvise notes in shanty (9)
# Prepared sage and onions, not initially added condiments (9)
#
# Word: shadowing
# ===============
# Error fetching pagination for 'shadowing': list index out of range
#
# Word: shamoying
# ===============
# Error fetching pagination for 'shamoying': list index out of range

# %%
# List of words
words = ["greens", "briefs", "orders", "creeps", "creeks", "greeks", "uraeus", "breeds", "greets", "dryers", "breeks", "triers"]
fetch_clues(words)
# Out:
# Word: greens
# ============
# Leaves simple starter of salad (6)
# Topless match, with players from one side in shades (6)
# Party supplying one of your five-a-day? (6)
# Signal to go south for vegetables (6)
# Political party on course (6)
# Leaves money for sex (6)
# Brussels sprouts? Good and never sent back by son! (6)
# Healthy food for party people (6)
# They're for putting on for party people (6)
# Renewable energy mostly supported by small political group (6)
# Ecowarriors putting on these (6)
# We are encouraged to like these environmentalists (6)
# Common sense's beginning for people in party (6)
# Good, then scoff up vegetables (6)
# Places for putting a group of politicians (6)
# Money for party veg (6)
# Nature lovers on the golf course (6)
# For putting on vegetables (6)
# Vegetables for use in bowls (6)
# They're for putting on vegetables (6)
# Looks like a seasick sailor's means of preventing scurvy? (6)
# Money for party politicians (6)
# Commons healthier for including these politicians? (6)
# Colours food (6)
# Vegetables prepared for putting on (6)
# Vegetables with holes in them (6)
# They're for putting on vegetables (6)
# Vegetables cut short at Troon (6)
# Vegetables identified by little flags (6)
#
# Word: briefs
# ============
# Prepares item that may be first on and last off? (6)
# Fibres woven into underwear (6)
# Prickly fibres in pants (6)
# Instructions for what to wear when it's too hot for long johns? (6)
# Initially baggy rear in evidence for some pants (6)
# Synopses, pants! (6)
# Lawyers showing underwear (6)
# Some underwear shows outlines (6)
# Fleeting sun brings out scanty wear (6)
# Abstracts underwear (6)
# Pants for instructions (6)
# Instructions to put a bit of flavour in cheeses (6)
# Gives someone the low-down underpants (6)
# Short introduction to short shorts (in the USA) (6)
# Barrister's clothing (6)
# Pants, breathing rapidly in extremely fast sprint initially (6)
# Son's put on short pants (6)
# Documents in folio about cheeses? On the contrary (6)
# Underwear sought by lawyers (6)
# Garments made from various fibres (6)
# Private parts in these lawyers' documents (6)
# Fibres working loose in underpants (6)
# Silky underwear? (6)
# Silky underwear? (6)
# Silky underwear? (6)
# Silky underwear? (6)
#
# Word: orders
# ============
# See 24 (6)
# Edicts from religious communities (6)
# See 8 (6)
# Sends for instructions (6)
# Directions taken by clergymen? (6)
# See 6 (6)
# See 6 (6)
# See 6 (6)
# See 6 (6)
# Nuns take what superiors give (6)
# Presumably 26 will have to have taken these directions (6)
# Yesteryear's book chain won't get book ____! (6)
# Demands wind instruments be cut by a third (6)
# Arranges wife's red roses to be collected on the way back (6)
# Arranges frontiers to exclude British (6)
# Edges trimmed to instructions (6)
# Sends away for books (6)
# Instructions the clergy take (6)
# Decorations one asks the salesman for (6)
# See 11 and 13 (6)
# Nuns are into these books (6)
# Grades nuns may have to take (6)
# They may be holy to take in the vicar (6)
# Sets to rights, according to instructions? (6)
# Directions taken by clergymen (6)
# Does Right Reverend get involved in monastic communities? (6)
# Instructions to top the edges (6)
# Sends away for books (6)
# Directs leader away from Scottish region (6)
# Given to soldiers but taken by clergymen (6)
#
# Word: creeps
# ============
# Moves stealthily and quietly among N American Indians (6)
# Moves stealthily and quietly among Native Americans (6)
# Toadies engendering a feeling of revulsion (6)
# Feeling of revulsion goes slowly (6)
# Feeling of revulsion goes slowly (6)
# Native American, a rider, treads softly (6)
#
# Word: creeks
# ============
# Constant smells from these inlets? (6)
# US rivers have constant stink at start of summer (6)
#
# Word: greeks
# ============
# Europeans prove noxious among extremists in Germans (6)
# Europeans who fought the people of Paris (6)
# Demos we should fear at the present time? (6)
# Europeans start to regroup into obsessive enthusiasts (6)
# Run in nerds' race (6)
# Europeans wanting end of disgusting smells (6)
#
# Word: uraeus
# ============
# Error fetching pagination for 'uraeus': list index out of range
#
# Word: breeds
# ============
# Creates endless colour in plots (6)
#
# Word: greets
# ============
# Welcomes political activists having time for North (6)
# Salutes grand pilot performing roll (6)
# Receives a pair of waders, say, putting head inside (6)
# Welcomes -- with tears? (6)
# Persuades to admit again and one receives (6)
#
# Word: dryers
# ============
#
# Word: breeks
# ============
# Error fetching pagination for 'breeks': list index out of range
#
# Word: triers
# ============
# German city's people making an effort (6)

# %%
# List of words
words = ["banister", "banished", "banisher", "banishes", "bondsmen", "bandsmen", "bankster", "bandster"]
fetch_clues(words)
# Out:
# Word: banister
# ==============
# Supporter is engaging in jokey comments (8)
# Is jesting about providing support on flight (8)
# Is jesting about providing support in flight (8)
# It reduces the risk of accidents on flight (8)
# Rail one's found in chaff (8)
# A guard is taking part in the repartee (8)
# It's reassuring if you feel shaky on the flight (8)
# Railing is included in joking (8)
# A security device for the flight (8)
# Sounds like the record-breaking athlete is going up the stairs? (8)
# Railing and repartee is accepted (8)
# Support at hand for those on flight (8)
# It reduces the risk of accidents on flight (8)
#
# Word: banished
# ==============
# Prohibition — one sent to outhouse is ostracised (8)
# One female in group is expelled (8)
# Black bird woman had driven away (8)
# Is he in the gang, or excluded? (8)
# Is the man in the group to be got rid of? (8)
# Is he in the orchestra or dismissed? (8)
# He's in bad trouble - sent off (8)
# Is he in the orchestra, or dismissed? (8)
# Is he in the orchestra, or dismissed? (8)
# Is he in the orchestra, or dismissed? (8)
# Is he in the orchestra, or dismissed? (8)
#
# Word: banisher
# ==============
# Error fetching pagination for 'banisher': list index out of range
#
# Word: banishes
# ==============
# Error fetching pagination for 'banishes': list index out of range
#
# Word: bondsmen
# ==============
# Error fetching pagination for 'bondsmen': list index out of range
#
# Word: bandsmen
# ==============
# Error fetching pagination for 'bandsmen': list index out of range
#
# Word: bankster
# ==============
# Error fetching pagination for 'bankster': list index out of range
#
# Word: bandster
# ==============
# Error fetching pagination for 'bandster': list index out of range

# %%
# List of words
words = ["overrun", "overran", "oneiron"]
fetch_clues(words)
# Out:
# Word: overrun
# =============
# Stretch too far above ladder (7)
# Finished? Manage not to finish on time (7)
# A couple of cricket events go on too long (7)
# Go too far, having finished marathon? (7)
# Take longer than expected with regard to marathon, say (7)
# Invade on account of race (7)
# Go too far in possibly maiden race? (7)
# OR to go too far? (7)
# Go right through finished work (7)
# Finished ride in storm (7)
# Two terms of cricket go on too long (7)
# Go beyond schedule in aspects of cricket (7)
# Take too long to find swamp (7)
# Heavily defeat old guard finally wiped out by king in battle (7)
# Swamp area beyond end of airstrip (7)
# Ended series, having exceeded time allowed (7)
# Cricketing references have gone on too long (7)
# Go too far -- finished on ladder (7)
# Go too far — invade and occupy (7)
# Two terms of cricket are too long (7)
# Take too long as king replacing duke in old battle (7)
# Two cricketing terms for swamp (7)
# Go too far and be swamped? (7)
# Too full of cricketing terms (7)
# Flood because of leak (7)
# Finished jog in storm (7)
# Plagued by one cricket term, then another (7)
# Stretch too far right with rugby players getting warmed up? (7)
# Terms in cricket go on too long (7)
# Go too far with surplus production (7)
# Finished with game point to exceed the limit (7)
# Go too far in maiden race (7)
# Elements of cricket go too far (7)
# Go past old battle site where duke became king (7)
# Move too fast to attack successfully (7)
# Ended series, having exceeded time allowed (7)
# Ended series, having exceeded time allowed (7)
# Ended series, having exceeded time allowed (7)
# Ended series, having exceeded time allowed (7)
# Manage too much and exceed the limit (7)
# Manage too much and exceed the limit (7)
# Manage too much and exceed the limit (7)
# Manage too much and exceed the limit (7)
#
# Word: overran
# =============
# Somewhat perverse — lunar revolution took longer than expected (7)
# Stormed taking part in undercover ransom (7)
# Sped too much, and exceeded the limit (7)
# Embraced by lover, ranger's overwhelmed (7)
# Conquered sin in love wagon (7)
# Foremost of royal artists invested in kiln, having exceeded production (7)
# Managed to follow maiden, but went too far (7)
# Went through and overwhelmed the enemy (7)
# Endless rage after some deliveries took too long (7)
#
# Word: oneiron
# =============
# Error fetching pagination for 'oneiron': list index out of range
